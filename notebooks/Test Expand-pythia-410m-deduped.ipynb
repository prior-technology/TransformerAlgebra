# %%
from transformer_algebra import *
import torch

model, tokenizer = load_pythia_model("EleutherAI/pythia-410m-deduped")
# Out:
# tokenizer_config.json:   0%|          | 0.00/396 [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/911M [00:00<?, ?B/s]
# The following generation flags are not valid and may be ignored: ['output_hidden_states']. Set `TRANSFORMERS_VERBOSITY=info` for more details.

# %%
# 2. Run on next token
T = PromptedTransformer(model, tokenizer, "Once upon")
# 2. Run on next token
x = T(" a")
x
# Out:
# T(embed(' a'))

# %%
# 3. Check predictions
predict(x).summary()
# Out:
# "Top 5 predictions:\n  1. ' time' (99.03%, logit=24.67)\n  2. ' Time' (0.09%, logit=17.71)\n  3. '\\n' (0.05%, logit=17.08)\n  4. ' certain' (0.05%, logit=17.08)\n  5. ' midnight' (0.04%, logit=16.91)"

# %%
logits(x)[" time"]
# Out:
# <unembed(' time'), T(embed(' a'))> = 24.67

# %%
expand(x)
# Out:
# LN^T((I + ΔB^1 + ΔB^2 T^1 + ΔB^3 T^2 + ΔB^4 T^3 + ΔB^5 T^4 + ΔB^6 T^5 + ΔB^7 T^6 + ΔB^8 T^7 + ΔB^9 T^8 + ΔB^10 T^9 + ΔB^11 T^10 + ΔB^12 T^11 + ΔB^13 T^12 + ΔB^14 T^13 + ΔB^15 T^14 + ΔB^16 T^15 + ΔB^17 T^16 + ΔB^18 T^17 + ΔB^19 T^18 + ΔB^20 T^19 + ΔB^21 T^20 + ΔB^22 T^21 + ΔB^23 T^22 + ΔB^24 T^23)embed(' a'))

# %%
contrib = contribution(expand(x), logits(x)[" time"])
contrib
# Out:
# Contributions to ⟨ time, LN(...)⟩:
#   embed(' a'): -0.06 (-0.2%)
#   ΔB^1: +0.85 (+3.5%)
#   ΔB^2 T^1: -0.64 (-2.6%)
#   ΔB^3 T^2: +0.50 (+2.0%)
#   ΔB^4 T^3: +0.53 (+2.2%)
#   ΔB^5 T^4: +0.99 (+4.1%)
#   ΔB^6 T^5: +0.75 (+3.1%)
#   ΔB^7 T^6: +1.35 (+5.5%)
#   ΔB^8 T^7: -0.01 (-0.1%)
#   ΔB^9 T^8: +0.85 (+3.5%)
#   ΔB^10 T^9: -0.82 (-3.4%)
#   ΔB^11 T^10: +1.07 (+4.4%)
#   ΔB^12 T^11: -0.66 (-2.7%)
#   ΔB^13 T^12: +1.43 (+5.9%)
#   ΔB^14 T^13: +1.46 (+6.0%)
#   ΔB^15 T^14: +1.29 (+5.3%)
#   ΔB^16 T^15: -0.36 (-1.5%)
#   ΔB^17 T^16: +2.93 (+12.0%)
#   ΔB^18 T^17: +7.31 (+29.9%)
#   ΔB^19 T^18: +3.30 (+13.5%)
#   ΔB^20 T^19: +1.07 (+4.4%)
#   ΔB^21 T^20: +0.65 (+2.7%)
#   ΔB^22 T^21: -0.46 (-1.9%)
#   ΔB^23 T^22: +0.48 (+1.9%)
#   ΔB^24 T^23: +0.61 (+2.5%)
#   Subtotal: 24.43
#   Beta term: 0.24
#   Total: 24.67

# %%
# 5. Drill down into significant blocks
for term, value, pct in contrib.top_k(3):
    if hasattr(term, 'expand'):
        print(f"\n{term}:")
        sub = term.expand()
        print(f"  Attention + MLP: {sub}")
# Out:
# ΔB^18 T^17:
#   Attention + MLP: ΔB^18_A T^17 + ΔB^18_M T^17
#
# ΔB^19 T^18:
#   Attention + MLP: ΔB^19_A T^18 + ΔB^19_M T^18
#
# ΔB^17 T^16:
#   Attention + MLP: ΔB^17_A T^16 + ΔB^17_M T^16

# %%
contrib.terms[16]
# Out:
# ΔB^16 T^15

# %%
level2 = expand(level1)
expand(level2)

# %%
T = PromptedTransformer(model, tokenizer, "The capital of Ireland")


x = T(" is")

# 3. Check predictions
print(predict(x).summary())

# 4. Expand and analyze
ex = expand(x)
logit = logits(x)[" Dublin"]
contrib = contribution(ex.inner, logit)
print(contrib.summary())

# 5. Drill down into significant blocks
for term, value, pct in contrib.top_k(3):
    if hasattr(term, 'expand'):
        print(f"\n{term}:")
        sub = term.expand()
        print(f"  Attention + MLP: {sub}")

# %%
contribution(predict(x),logits(x)[" time"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 contribution(predict(x),logits(x)[" time"])
#
# File ~/AgentWorkspace/TransformerAlgebra/src/transformer_algebra/core.py:1420, in contribution(expr, vector, transformer)
#    1417     xformer = None
#    1419 else:
# -> 1420     raise TypeError(
#    1421         f"Expected LayerNormApplication or VectorSum, got {type(expr).__name__}"
#    1422     )
#    1424 # Resolve the vector argument
#    1425 label = ""
#
# TypeError: Expected LayerNormApplication or VectorSum, got ProbabilityMapping
